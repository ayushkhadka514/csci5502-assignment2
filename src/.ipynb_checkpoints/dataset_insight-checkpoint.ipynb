# %%
'''
IMPORTS
'''

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

sns.set(style="whitegrid")
pd.set_option("display.max_columns", None)

# %%
filename = 'student.csv' #Change to filename .csv

csv_path = "../data/" + filename
df = pd.read_csv(csv_path)

# %%
df.head()
# Out:
#   Decision Sex_assigned_at_birth     State   GPA  WorkExp_yrs  TestScore_1000  \
# 0    Admit                Female   Florida  3.54          0.7             965
# 1    Admit                Female   Florida  3.55          0.0             962
# 2    Admit                Female  Colorado  3.59          1.7             969
# 3    Admit                Female  Colorado   3.6          0.9             969
# 4    Admit                Female  Colorado   3.6          1.2             967
#
#    WritingScore_100  VolunteerLevel_5
# 0              90.0               1.0
# 1              97.0               0.0
# 2              93.0               0.0
# 3              97.0               2.0
# 4              94.0               2.0

# %%
'''
General Shape
'''

print("Shape:", df.shape)
print("\nColumn Types:")
display(df.dtypes)
# Out:
# Shape: (87, 8)
#
# Column Types:
# Decision                  object
# Sex_assigned_at_birth     object
# State                     object
# GPA                       object
# WorkExp_yrs              float64
# TestScore_1000             int64
# WritingScore_100         float64
# VolunteerLevel_5         float64
# dtype: object

# %%
'''
Missing Values
'''
missing_summary = pd.DataFrame({
    "missing_count": df.isna().sum(),
    "missing_percent": df.isna().mean() * 100
}).sort_values("missing_percent", ascending=False)

display(missing_summary)
# Out:
#                        missing_count  missing_percent
# WritingScore_100                   1         1.149425
# VolunteerLevel_5                   1         1.149425
# Decision                           0         0.000000
# Sex_assigned_at_birth              0         0.000000
# GPA                                0         0.000000
# State                              0         0.000000
# TestScore_1000                     0         0.000000
# WorkExp_yrs                        0         0.000000

# %%
print("Duplicate rows:", df.duplicated().sum())

constant_cols = [c for c in df.columns if df[c].nunique(dropna=False) == 1]
print("Columns with one unique value:", constant_cols)

high_missing = missing_summary[missing_summary["missing_percent"] > 50]
print("Columns with >50% missing:")
display(high_missing)
# Out:
# Duplicate rows: 0
# Columns with one unique value: []
# Columns with >50% missing:
# Empty DataFrame
# Columns: [missing_count, missing_percent]
# Index: []

# %%
numeric_cols = df.select_dtypes(include=np.number).columns.tolist()
categorical_cols = df.select_dtypes(exclude=np.number).columns.tolist()

numeric_cols, categorical_cols
# Out:
# (['WorkExp_yrs', 'TestScore_1000', 'WritingScore_100', 'VolunteerLevel_5'],
#  ['Decision', 'Sex_assigned_at_birth', 'State', 'GPA'])

# %%
if categorical_cols:
    cat_col = categorical_cols[0]
    cat_counts = df[cat_col].value_counts(dropna=False)
    cat_percent = df[cat_col].value_counts(normalize=True, dropna=False) * 100

    cat_summary = pd.DataFrame({
        "count": cat_counts,
        "percent": cat_percent.round(2)
    })

    display(cat_summary)
# Out:
#           count  percent
# Decision
# Admit        34    39.08
# Decline      27    31.03
# Waitlist     24    27.59
# Banana        1     1.15
# Maybe         1     1.15

# %%
def numeric_summary(series):
    q1 = series.quantile(0.25)
    q3 = series.quantile(0.75)
    iqr = q3 - q1

    return {
        "min": series.min(),
        "max": series.max(),
        "mean": series.mean(),
        "median": series.median(),
        "mode": series.mode().iloc[0] if not series.mode().empty else np.nan,
        "std": series.std(),
        "IQR": iqr,
        "outliers_1.5IQR": ((series < q1 - 1.5*iqr) | (series > q3 + 1.5*iqr)).sum()
    }

num_stats = {col: numeric_summary(df[col].dropna()) for col in numeric_cols[:2]}
pd.DataFrame(num_stats)
# Out:
#                  WorkExp_yrs  TestScore_1000
# min                 0.000000       85.000000
# max                 9.200000     9660.000000
# mean                2.095402      966.770115
# median              1.500000      869.000000
# mode                1.700000      969.000000
# std                 1.722485      950.144710
# IQR                 1.350000      197.500000
# outliers_1.5IQR     8.000000        2.000000

# %% [markdown]
# **VISUALIZATIONS**

# %%
#HISTOGRAM
df[numeric_cols[0]].hist(bins=30)
plt.title(f"Histogram of {numeric_cols[0]}")
plt.xlabel(numeric_cols[0])
plt.ylabel("Frequency")
plt.show()

# %%
#BOXPLOT
sns.boxplot(x=df[numeric_cols[0]])
plt.title(f"Boxplot of {numeric_cols[0]}")
plt.xlabel(numeric_cols[0])
plt.show()

# %%
#BAR CHART
sns.countplot(y=df[cat_col], order=df[cat_col].value_counts().index)
plt.title(f"Counts of {cat_col}")
plt.xlabel("Count")
plt.ylabel(cat_col)
plt.show()

# %%
#Scatterpkot

if len(numeric_cols) >= 2:
    sns.scatterplot(
        x=df[numeric_cols[0]],
        y=df[numeric_cols[1]]
    )
    plt.title(f"{numeric_cols[0]} vs {numeric_cols[1]}")
    plt.xlabel(numeric_cols[0])
    plt.ylabel(numeric_cols[1])
    plt.show()

# %%
#Heatmap
corr = df[numeric_cols].corr()

sns.heatmap(corr, annot=True, cmap="coolwarm")
plt.title("Correlation Heatmap")
plt.show()

# %%
insights = []

# Missingness
if high_missing.shape[0] > 0:
    insights.append(
        f"{len(high_missing)} columns have more than 50% missing values, which may limit analysis reliability."
    )

# Outliers
for col in numeric_cols[:2]:
    stats = numeric_summary(df[col].dropna())
    if stats["outliers_1.5IQR"] > 0:
        insights.append(
            f"{col} contains {stats['outliers_1.5IQR']} potential outliers based on the 1.5×IQR rule."
        )

# Correlation
if len(numeric_cols) >= 2:
    max_corr = corr.abs().unstack().sort_values(ascending=False)
    max_corr = max_corr[max_corr < 1].idxmax()
    insights.append(
        f"{max_corr[0]} and {max_corr[1]} show the strongest correlation among numeric variables."
    )

# Categorical dominance
for cat_col in categorical_cols:
    cat_counts = df[cat_col].value_counts(dropna=False)
    cat_percent = cat_counts / cat_counts.sum() * 100

    # Categorical dominance
    top_cat = cat_counts.idxmax()
    insights.append(
        f"The most common value in {cat_col} is '{top_cat}', representing {cat_percent[top_cat]:.1f}% of records."
    )

for i, insight in enumerate(insights[:10], 1):
    print(f"{i}. {insight}")
# Out:
# 1. WorkExp_yrs contains 8 potential outliers based on the 1.5×IQR rule.
# 2. TestScore_1000 contains 2 potential outliers based on the 1.5×IQR rule.
# 3. TestScore_1000 and WritingScore_100 show the strongest correlation among numeric variables.
# 4. The most common value in Decision is 'Admit', representing 39.1% of records.
# 5. The most common value in Sex_assigned_at_birth is 'Female', representing 63.2% of records.
# 6. The most common value in State is 'Florida', representing 41.4% of records.
# 7. The most common value in GPA is '3.8', representing 5.7% of records.

# %%
limitations = [
    "Missing data may bias summary statistics and correlations.",
    "Outlier detection is based solely on the 1.5×IQR rule and may flag valid extreme values.",
    "No external validation or ground truth is available to assess data accuracy.",
    "If the dataset is observational, correlations do not imply causation."
]

for item in limitations:
    print("-", item)
# Out:
# - Missing data may bias summary statistics and correlations.
# - Outlier detection is based solely on the 1.5×IQR rule and may flag valid extreme values.
# - No external validation or ground truth is available to assess data accuracy.
# - If the dataset is observational, correlations do not imply causation.
